# %% [markdown]
# ![imagen](./img/ejercicios.png)
#
# # Ejercicio SQL
# Para este ejercicio usaremos una base de datos de Pokemon. **Asegúrante que tienes el CSV "pokemon.csv" en la misma carpeta donde está este Notebook**. Realiza los siguientes apartados:
#
# 1. Obten una tabla con todos los campos
# 2. Obten una tabla con los campos "Name", "Type 1", "Type 2"
# 3. Obten la misma tabla que el apartado anterior, pero en este caso renombrando los campos al castellano.
# 4. ¿Cuales son todos los "Type 1" diferentes?
# 5. ¿Cuales son todos los "Type 1" y "Type 2" diferentes?
# 6. ¿Cuáles son los pokemon de agua? "Type 1" = "Water"
# 7. Obtén una tabla con los pokemon legendarios
# 8. Obtén una tabla con los pokemon legendarios de fuego ("Type 1" = "Fire")
# 9. Obtén una tabla con los pokemon cuyo nombre empieze por "W" y tenga una defensa mayor de 100 puntos
# 10. Saca una tabla con los pokemon de la primera generación, que NO sean "Type 1" = "Psychic" y tengan una velocidad superior a 130
# 11. ¿Cuál es el pokemon con el ataque más alto?
# 12. ¿Cuál es la media de la defensa de todos los pokemon?
# 13. ¿Cuál es la media de la defensa por generación?
# 14. Calcula el máximo HP por "Type 1"
#
# **NOTA**: se recomienda añadir un `LIMIT 5` en la mayoría de apartados para evitar grandes outputs de las queries.

# %%
# Importamos paquetes
import pandas as pd
import sqlite3
cnx = sqlite3.connect(':memory:')

# Importamos datos de un CSV
df = pd.read_csv('pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Pasamos el DataFrame de Pandas a SQL
df.to_sql('pokemon', con=cnx, if_exists='append', index=False)

# Definimos la función para hacer queries.
def sql_query(query):
    return pd.read_sql(query, cnx)

# %%
# 1. Obten una tabla con todos los campos
query = '''
SELECT * 
FROM Pokemon
'''

sql_query(query)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire    None    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1          0
# 1         80       80     60           1          0
# 2        100      100     80           1          0
# 3        122      120     80           1          0
# 4         60       50     65           1          0
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6          1
# 796      160      110    110           6          1
# 797      150      130     70           6          1
# 798      170      130     80           6          1
# 799      130       90     70           6          1
#
# [800 rows x 13 columns]

# %%
# 2. Obten una tabla con los campos "Name", "Type 1", "Type 2"
query = '''
SELECT Name,'Type 1','Type 2'
FROM Pokemon
'''

sql_query(query)
# Out:
#                       Name 'Type 1' 'Type 2'
# 0                Bulbasaur   Type 1   Type 2
# 1                  Ivysaur   Type 1   Type 2
# 2                 Venusaur   Type 1   Type 2
# 3    VenusaurMega Venusaur   Type 1   Type 2
# 4               Charmander   Type 1   Type 2
# ..                     ...      ...      ...
# 795                Diancie   Type 1   Type 2
# 796    DiancieMega Diancie   Type 1   Type 2
# 797    HoopaHoopa Confined   Type 1   Type 2
# 798     HoopaHoopa Unbound   Type 1   Type 2
# 799              Volcanion   Type 1   Type 2
#
# [800 rows x 3 columns]

# %%
# 3. Obten la misma tabla que el apartado anterior, pero en este caso renombrando los campos al castellano.
query = '''
SELECT Name as 'Nombre','Type 1' as 'Tipo 1','Type 2' as 'Tipo 2'
FROM Pokemon
'''

sql_query(query)
# Out:
#                     Nombre  Tipo 1  Tipo 2
# 0                Bulbasaur  Type 1  Type 2
# 1                  Ivysaur  Type 1  Type 2
# 2                 Venusaur  Type 1  Type 2
# 3    VenusaurMega Venusaur  Type 1  Type 2
# 4               Charmander  Type 1  Type 2
# ..                     ...     ...     ...
# 795                Diancie  Type 1  Type 2
# 796    DiancieMega Diancie  Type 1  Type 2
# 797    HoopaHoopa Confined  Type 1  Type 2
# 798     HoopaHoopa Unbound  Type 1  Type 2
# 799              Volcanion  Type 1  Type 2
#
# [800 rows x 3 columns]

# %%
# 4. ¿Cuales son todos los "Type 1" diferentes?
query = '''
SELECT DISTINCT "Type 1"
FROM Pokemon
'''

sql_query(query)
# Out:
#       Type 1
# 0      Grass
# 1       Fire
# 2      Water
# 3        Bug
# 4     Normal
# 5     Poison
# 6   Electric
# 7     Ground
# 8      Fairy
# 9   Fighting
# 10   Psychic
# 11      Rock
# 12     Ghost
# 13       Ice
# 14    Dragon
# 15      Dark
# 16     Steel
# 17    Flying

# %%
# 5. ¿Cuales son todos los "Type 1" y "Type 2" diferentes?
query = '''
SELECT DISTINCT "Type 1", "Type 2"
FROM Pokemon
'''

sql_query(query)
# Out:
#       Type 1  Type 2
# 0      Grass  Poison
# 1       Fire    None
# 2       Fire  Flying
# 3       Fire  Dragon
# 4      Water    None
# ..       ...     ...
# 149    Ghost   Grass
# 150   Flying  Dragon
# 151  Psychic   Ghost
# 152  Psychic    Dark
# 153     Fire   Water
#
# [154 rows x 2 columns]

# %%
# 6. ¿Cuáles son los pokemon de agua? "Type 1" = "Water"
query = '''
SELECT *
FROM Pokemon
WHERE "Type 1" like "%Water%"
'''

sql_query(query)
# Out:
#        #                     Name Type 1 Type 2  Total  HP  Attack  Defense  \
# 0      7                 Squirtle  Water   None    314  44      48       65
# 1      8                Wartortle  Water   None    405  59      63       80
# 2      9                Blastoise  Water   None    530  79      83      100
# 3      9  BlastoiseMega Blastoise  Water   None    630  79     103      120
# 4     54                  Psyduck  Water   None    320  50      52       48
# ..   ...                      ...    ...    ...    ...  ..     ...      ...
# 107  656                  Froakie  Water   None    314  41      56       40
# 108  657                Frogadier  Water   None    405  54      63       52
# 109  658                 Greninja  Water   Dark    530  72      95       67
# 110  692                Clauncher  Water   None    330  50      53       62
# 111  693                Clawitzer  Water   None    500  71      73       88
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         50       64     43           1          0
# 1         65       80     58           1          0
# 2         85      105     78           1          0
# 3        135      115     78           1          0
# 4         65       50     55           1          0
# ..       ...      ...    ...         ...        ...
# 107       62       44     71           6          0
# 108       83       56     97           6          0
# 109      103       71    122           6          0
# 110       58       63     44           6          0
# 111      120       89     59           6          0
#
# [112 rows x 13 columns]

# %%
# 7. Obtén una tabla con los pokemon legendarios
query = '''
SELECT *
FROM Pokemon
WHERE Legendary like 1
'''

sql_query(query)
# Out:
#       #                 Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 0   144             Articuno       Ice    Flying    580   90      85      100
# 1   145               Zapdos  Electric    Flying    580   90      90       85
# 2   146              Moltres      Fire    Flying    580   90     100       90
# 3   150               Mewtwo   Psychic      None    680  106     110       90
# 4   150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# ..  ...                  ...       ...       ...    ...  ...     ...      ...
# 60  719              Diancie      Rock     Fairy    600   50     100      150
# 61  719  DiancieMega Diancie      Rock     Fairy    700   50     160      110
# 62  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110       60
# 63  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160       60
# 64  721            Volcanion      Fire     Water    600   80     110      120
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        95      125     85           1          1
# 1       125       90    100           1          1
# 2       125       85     90           1          1
# 3       154       90    130           1          1
# 4       154      100    130           1          1
# ..      ...      ...    ...         ...        ...
# 60      100      150     50           6          1
# 61      160      110    110           6          1
# 62      150      130     70           6          1
# 63      170      130     80           6          1
# 64      130       90     70           6          1
#
# [65 rows x 13 columns]

# %%
# 8. Obtén una tabla con los pokemon legendarios de fuego ("Type 1" = "Fire")
query = '''
SELECT *
FROM Pokemon
WHERE (Legendary like 1) and "Type 2" like "%Fire%"
'''

sql_query(query)
# Out:
#      #                   Name   Type 1 Type 2  Total   HP  Attack  Defense  \
# 0  383  GroudonPrimal Groudon   Ground   Fire    770  100     180      160
# 1  494                Victini  Psychic   Fire    600  100     100      100
# 2  643               Reshiram   Dragon   Fire    680  100     120      100
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      150       90     90           3          1
# 1      100      100    100           5          1
# 2      150      120     90           5          1

# %%
# 9. Obtén una tabla con los pokemon cuyo nombre empieze por "W" y tenga una defensa mayor de 100 puntos
query = '''
SELECT *
FROM Pokemon
WHERE (Name like "W%") and ("Sp.Def" > 100)
'''

sql_query(query)
# Out:
#       #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0     8            Wartortle    Water    None    405   59      63       80
# 1    13               Weedle      Bug  Poison    195   40      35       30
# 2    40           Wigglytuff   Normal   Fairy    435  140      70       45
# 3    70           Weepinbell    Grass  Poison    390   65      90       50
# 4   110              Weezing   Poison    None    490   65      90      120
# 5   194               Wooper    Water  Ground    210   55      45       45
# 6   202            Wobbuffet  Psychic    None    405  190      33       58
# 7   265              Wurmple      Bug    None    195   45      45       35
# 8   278              Wingull    Water  Flying    270   40      30       30
# 9   293              Whismur   Normal    None    240   64      51       23
# 10  320              Wailmer    Water    None    400  130      70       35
# 11  321              Wailord    Water    None    500  170      90       45
# 12  340             Whiscash    Water  Ground    468  110      78       73
# 13  360               Wynaut  Psychic    None    260   95      23       48
# 14  365              Walrein      Ice   Water    530  110      80       90
# 15  413  WormadamPlant Cloak      Bug   Grass    424   60      59       85
# 16  413  WormadamSandy Cloak      Bug  Ground    424   60      79      105
# 17  413  WormadamTrash Cloak      Bug   Steel    424   60      69       95
# 18  461              Weavile     Dark     Ice    510   70     120       65
# 19  505              Watchog   Normal    None    420   60      85       69
# 20  527               Woobat  Psychic  Flying    313   55      45       43
# 21  544           Whirlipede      Bug  Poison    360   40      55       99
# 22  547           Whimsicott    Grass   Fairy    480   60      67       85
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       80     58           1          0
# 1        20       20     50           1          0
# 2        85       50     45           1          0
# 3        85       45     55           1          0
# 4        85       70     60           1          0
# 5        25       25     15           2          0
# 6        33       58     33           2          0
# 7        20       30     20           3          0
# 8        55       30     85           3          0
# 9        51       23     28           3          0
# 10       70       35     60           3          0
# 11       90       45     60           3          0
# 12       76       71     60           3          0
# 13       23       48     23           3          0
# 14       95       90     65           3          0
# 15       79      105     36           4          0
# 16       59       85     36           4          0
# 17       69       95     36           4          0
# 18       45       85    125           4          0
# 19       60       69     77           5          0
# 20       55       43     72           5          0
# 21       40       79     47           5          0
# 22       77       75    116           5          0

# %%
# 10. Saca una tabla con los pokemon de la primera generación, que NO sean "Type 1" = "Psychic" y tengan una velocidad superior a 130
query = '''
SELECT *
FROM Pokemon
WHERE (Generation like 1) and ('Type 1' != "Psychic") and (Speed > 130)
'''

sql_query(query)
# Out:
#      #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0   15      BeedrillMega Beedrill       Bug  Poison    495   65     150
# 1   65      AlakazamMega Alakazam   Psychic    None    590   55      50
# 2  101                  Electrode  Electric    None    480   60      50
# 3  142  AerodactylMega Aerodactyl      Rock  Flying    615   80     135
# 4  150        MewtwoMega Mewtwo Y   Psychic    None    780  106     150
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       40       15       80    145           1          0
# 1       65      175       95    150           1          0
# 2       70       80       80    140           1          0
# 3       85       70       95    150           1          0
# 4       70      194      120    140           1          1

# %%
# 11. ¿Cuál es el pokemon con el ataque más alto?
query = '''
SELECT Name, Attack
FROM Pokemon
WHERE Attack = (SELECT MAX(Attack) FROM pokemon)
'''

sql_query(query)
# Out:
#                   Name  Attack
# 0  MewtwoMega Mewtwo X     190

# %%
# 12. ¿Cuál es la media de la defensa de todos los pokemon?
query = '''
SELECT AVG(Defense) as avg
FROM Pokemon
'''

sql_query(query)
# Out:
#        avg
# 0  73.8425

# %%
# 13. ¿Cuál es la media de la defensa por generación?
query = '''
SELECT Generation, AVG(Defense) as avg
FROM Pokemon
GROUP BY Generation
'''

sql_query(query)
# Out:
#    Generation        avg
# 0           1  70.861446
# 1           2  73.386792
# 2           3  74.100000
# 3           4  78.132231
# 4           5  72.327273
# 5           6  76.682927

# %%
# Apartado 14. Calcula el máximo HP por "Type 1"
query = '''
SELECT 
  "Type 1",
  MAX(HP) AS "Max_HP"
FROM Pokemon
GROUP BY "Type 1"
ORDER BY "Max_HP" DESC;
'''

sql_query(query)
# Out:
#       Type 1  Max HP
# 0        Bug      86
# 1       Dark     126
# 2     Dragon     125
# 3   Electric      90
# 4      Fairy     126
# 5   Fighting     144
# 6       Fire     115
# 7     Flying      85
# 8      Ghost     150
# 9      Grass     123
# 10    Ground     115
# 11       Ice     110
# 12    Normal     255
# 13    Poison     105
# 14   Psychic     190
# 15      Rock     123
# 16     Steel     100
# 17     Water     170
